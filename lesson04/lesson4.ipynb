# %% [markdown]
# Урок 6.
#
# Системы линейных уравнений. Часть 1

# %% [markdown]
# 1. Решить систему уравнений методом Гаусса:
#
# $\begin{cases}
# x_1 + x_2 - x_3 - 2x_4 = 0 \\
# 2x_1 + x_2 - x_3 + x_4 = -2 \\
# x_1 + x_2 - 3x_3 + x_4 = 4
# \end{cases}
# $

# %% [markdown]
# Запишем в виде матрицы
#
# $\begin{pmatrix}
# \left. \begin{matrix}
# 1 & 1 & -1 & -2 \\
# 2 & 1 & -1 & 1 \\
# 1 & 1 & -3 & 4
# \end{matrix}
# \right|\begin{matrix}
# 0 \\
# -2 \\
# 4
# \end{matrix}
# \end{pmatrix}
# $

# %% [markdown]
# Путем несложных вычислений приходим к
#
# $\begin{pmatrix}
# \left. \begin{matrix}
# 1 & 1 & -1 & -2 \\
# 0 & -1 & 1 & -3 \\
# 0 & 0 & 4 & 2
# \end{matrix}
# \right|\begin{matrix}
# 0 \\
# -2 \\
# 4
# \end{matrix}
# \end{pmatrix}
# $

# %% [markdown]
# Имеет бесконечное множество решений.
#
# Выразим что нибудь:
#
# $x_3 = c$
#
# $x_4 = 2 - 2c$
#
# $x_2 = 3с$
#
# $x_1 = 2c - 4$
#
# Тогда скажем при $x_3 = 1$ получаем
# $x_4 = 0$, $x_2 = 3$, $x_1 = -2$

# %% [markdown]
# Проверял и решал на бумажке - здесь не привожу

# %% [markdown]
# 2. Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений:
#
# a). $\begin{cases}
# 3x_1 - x_2 + x_3 = 4 \\
# 2x_1 - 5x_2 - 3x_3 = -17 \\
# x_1 + x_2 - x_3 = 0
# \end{cases}
# $
#
# б). $\begin{cases}
# 2x_1 - 4x_2 + 6x_3 = 1 \\
# x_1 - 2x_2 + 3x_3 = -2 \\
# 3x_1 - 6x_2 + 9x_3 = 5
# \end{cases}
# $
#
# в). $\begin{cases}
# x_1 + 2x_2 + 5x_3 = 4 \\
# 3x_1 + 1x_2 - 8x_3 = -2
# \end{cases}
# $

# %% [markdown]
# Распишем в матрицы

# %% [markdown]
# а) $\begin{pmatrix}
# \left. \begin{matrix}
# 3 & -1 & 1 \\
# 2 & -5 & -3 \\
# 1 & 1 & -1
# \end{matrix}
# \right|\begin{matrix}
# 4 \\
# -17 \\
# 0
# \end{matrix}
# \end{pmatrix}
# $
# ранг равен 3, а ранг расширенной равен тоже 3
#
# Похоже система совместна и имеет одно решение

# %% [markdown]
# б) $\begin{pmatrix}
# \left. \begin{matrix}
# 2 & -4 & 6 \\
# 1 & -2 & 3 \\
# 3 & -6 & 9
# \end{matrix}
# \right|\begin{matrix}
# 1 \\
# -2 \\
# 5
# \end{matrix}
# \end{pmatrix}
# $
# ранг равен 1, а ранг расширенной равен 2
#
# Похоже система несовместна

# %% [markdown]
# б) $\begin{pmatrix}
# \left. \begin{matrix}
# 1 & 2 & 5 \\
# 3 & 1 & -8
# \end{matrix}
# \right|\begin{matrix}
# 4 \\
# -2
# \end{matrix}
# \end{pmatrix}
# $
# ранг равен 2, а ранг расширенной равен тоже 2
#
# Система совместна и имеет бесконечное количество решений

# %% [markdown]
# 3. Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей
#
# $\begin{pmatrix}
# \left. \begin{matrix}
# 1 & 3 & -2 & 4 \\
# 0 & 5 & 0 & 1 \\
# 0 & 0 & 3 & 0 \\
# 0 & 0 & 0 & 2
# \end{matrix}
# \right|\begin{matrix}
# 3 \\
# 2 \\
# 4 \\
# 1
# \end{matrix}
# \end{pmatrix}
# $

# %% [markdown]
# Ранг основной равен 4, ранг расширенной тоже 4 - система совместна и имеет одно решение.

# %% [markdown]
# 4. Дана система линейных уравнений, заданная расширенной матрицей
#
# $\begin{pmatrix}
# \left. \begin{matrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# 7 & 8 & 9
# \end{matrix}
# \right|\begin{matrix}
# a \\
# b \\
# c
# \end{matrix}
# \end{pmatrix}
# $
#
# Найти соотношение между параметрами  𝑎 ,  𝑏  и  𝑐 , при которых система является несовместной.

# %% [markdown]
# Ранг исходной равен 2, значит, чтобы система стала несовместной - нужно, чтобы ранг расширенной был = 3..
# Не знаю, как это нужно было решать, я брал минор 3 порядка с участием последнего столбца - и подбирал значения, чтобы его определитель не был равен 0.. получил a = 1, b = 3, c = 6...
#
# Проверил так-же другие значения с тем-же соотношением - вроде тоже работает.
#
# Получается b = 3a, c = 6a, ну a - можно выбрать произвольным

# %% [markdown]
# Вторую часть пока не решал, но обязательно доберусь
